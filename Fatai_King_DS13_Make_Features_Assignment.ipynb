# %% [markdown]
# <a href="https://colab.research.google.com/github/fataik1/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/Fatai_King_DS13_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####

import pandas as pd

# %%
# Open the Ames Iowa Housing Dataset:
df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')

df.shape
# Out:
# (1460, 81)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
pd.set_option('display.max_rows', 100)

df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
df.isnull()
# Out:
#          Id  MSSubClass  MSZoning  ...  SaleType  SaleCondition  SalePrice
# 0     False       False     False  ...     False          False      False
# 1     False       False     False  ...     False          False      False
# 2     False       False     False  ...     False          False      False
# 3     False       False     False  ...     False          False      False
# 4     False       False     False  ...     False          False      False
# ...     ...         ...       ...  ...       ...            ...        ...
# 1455  False       False     False  ...     False          False      False
# 1456  False       False     False  ...     False          False      False
# 1457  False       False     False  ...     False          False      False
# 1458  False       False     False  ...     False          False      False
# 1459  False       False     False  ...     False          False      False
#
# [1460 rows x 81 columns]

# %%
df_small = df[['TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'SalePrice']]

df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
# Lets add up all of the square footage to get a single square footage 
# column for the entire dataset

# Using bracket syntax to make a new 'TotalSquareFootage' column

df_small['TotalSF'] = df_small['TotalBsmtSF'] + df_small['1stFlrSF'] + df_small['2ndFlrSF'] 

df_small.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF
# 0          856       856       854     208500     2566
# 1         1262      1262         0     181500     2524
# 2          920       920       866     223500     2706
# 3          756       961       756     140000     2473
# 4         1145      1145      1053     250000     3343

# %%
# Dot Syntax for accessing columns
df_small.TotalBsmtSF
# Out:
# 0        856
# 1       1262
# 2        920
# 3        756
# 4       1145
#         ...
# 1455     953
# 1456    1542
# 1457    1152
# 1458    1078
# 1459    1256
# Name: TotalBsmtSF, Length: 1460, dtype: int64

# %%
# Bracket Syntax for accessing columns
df_small['TotalBsmtSF']
# Out:
# 0        856
# 1       1262
# 2        920
# 3        756
# 4       1145
#         ...
# 1455     953
# 1456    1542
# 1457    1152
# 1458    1078
# 1459    1256
# Name: TotalBsmtSF, Length: 1460, dtype: int64

# %%
# Lets make a nother new column that is 'PricePerSqFt' by
# dividing the price by the square footage

df_small['PricePerSqFt'] = df_small['SalePrice'] / df_small['TotalSF']

df_small.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF  PricePerSqFt
# 0          856       856       854     208500     2566     81.254871
# 1         1262      1262         0     181500     2524     71.909667
# 2          920       920       866     223500     2706     82.594235
# 3          756       961       756     140000     2473     56.611403
# 4         1145      1145      1053     250000     3343     74.783129

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-02-12 04:35:02--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [          <=>       ]  18.57M   226KB/s               ^C

# %%
#Unzip to extract the csv from the zip folder
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of LoanStats_2018Q4.csv.zip or
#         LoanStats_2018Q4.csv.zip.zip, and cannot find LoanStats_2018Q4.csv.zip.ZIP, period.

# %%
#can also use bash/shell commands to look at the raw file
# !head LoanStats_2018Q4.csv
# Out:
# head: cannot open 'LoanStats_2018Q4.csv' for reading: No such file or directory

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","3537.82","3537.82","2842.6","2842.60","2062.18","780.42","0.0","0.0","0.0","Jan-2020","190.21","Feb-2020","Jan-2020","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
import pandas as pd
pd.set_option('display.max_rows', 150)

# %%
# Read in the CSV
df = pd.read_csv('LoanStats_2018Q4.csv')
print(df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-a8b7ec6d1ef8> in <module>()
# ----> 1 df = pd.read_csv('LoanStats_2018Q4.csv')
#       2 print(df.shape)
#       3 df.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
# ...

# %%
# We can fix the header problem by using the 'skiprows' parameter
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1)
print(df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-307e0ac90680> in <module>()
# ----> 1 df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1)
#       2 print(df.shape)
#       3 df.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
# Sum null values by column and sort from least to greatest

df.isnull().sum().sort_values()
# Out:
# inq_fi                                             2
# delinq_amnt                                        2
# chargeoff_within_12_mths                           2
# acc_open_past_24mths                               2
# inq_last_12m                                       2
# total_cu_tl                                        2
# total_rev_hi_lim                                   2
# max_bal_bc                                         2
# open_rv_24m                                        2
# open_rv_12m                                        2
# total_bal_il                                       2
# open_il_24m                                        2
# hardship_flag                                      2
# open_act_il                                        2
# open_acc_6m                                        2
# tot_cur_bal                                        2
# tot_coll_amt                                       2
# acc_now_delinq                                     2
# ...

# %%
# Address the extra NaNs in each column by skipping the footer as well.
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1, skipfooter=2)
print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-721a050c70b7> in <module>()
# ----> 1 df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1, skipfooter=2)
#       2 print(df.shape)
#       3 df.head()
#
# ...

# %%
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
# acc_open_past_24mths                               0
# inq_last_12m                                       0
# total_cu_tl                                        0
# total_rev_hi_lim                                   0
# max_bal_bc                                         0
# open_rv_24m                                        0
# open_rv_12m                                        0
# total_bal_il                                       0
# open_il_24m                                        0
# hardship_flag                                      0
# open_act_il                                        0
# open_acc_6m                                        0
# tot_cur_bal                                        0
# tot_coll_amt                                       0
# acc_now_delinq                                     0
# ...

# %%
df = df.drop(['url', 'member_id', 'desc', 'id'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-aa20753d9a8d> in <module>()
# ----> 1 df = df.drop(['url', 'member_id', 'desc', 'id'], axis=1)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_percentage settlement_term
# 0      35000        35000  ...                    NaN             NaN
# 1       5000         5000  ...                    NaN             NaN
# 2      10000        10000  ...                    NaN             NaN
# 3      17100        17100  ...                    NaN             NaN
# 4       4000         4000  ...                    NaN             NaN
#
# [5 rows x 140 columns]

# %%
# Look at the first 10 values of the int_rate column
df['int_rate'].head(10)
# Out:
# 0     14.47%
# 1     22.35%
# 2     23.40%
# 3     18.94%
# 4     10.72%
# 5     11.31%
# 6     11.31%
# 7     11.80%
# 8     11.80%
# 9     18.94%
# Name: int_rate, dtype: object

# %%
df['int_rate'][:10]
# Out:
# 0     14.47%
# 1     22.35%
# 2     23.40%
# 3     18.94%
# 4     10.72%
# 5     11.31%
# 6     11.31%
# 7     11.80%
# 8     11.80%
# 9     18.94%
# Name: int_rate, dtype: object

# %%
# Look at a specific value from the int_rate column
df['int_rate'][0]
# Out:
# ' 14.47%'

# %%
df['int_rate'].describe()
# Out:
# count      128412
# unique         46
# top        13.56%
# freq         6972
# Name: int_rate, dtype: object

# %%
# Lets start with just fixing a single string.
# If we can fix one, we can usually fix all of them

int_rate = ' 13.56%'

# %%
# If i call .strip() but don't pass in any values into the ()
# .strip() will remove any leading or trailing whitespace

int_rate.strip()
# Out:
# '13.56%'

# %%
int_rate.strip("%")
# Out:
# ' 13.56'

# %%
int_rate.strip().strip('%')
# Out:
# '13.56'

# %%
# "Cast" the string value to a float

float("8.5")
# Out:
# 8.5

# %%
float(int_rate.strip().strip('%'))
# Out:
# 13.56

# %%
float(df['int_rate'][0].strip().strip('%'))
# Out:
# 14.47

# %%
float(df['int_rate'][1].strip().strip('%'))
# Out:
# 22.35

# %%
# We can do this with a for loop

new_int_rate = []

for cell in df['int_rate']:
  new_int_rate.append(float(cell.strip().strip('%')))

new_int_rate
# Out:
# [14.47,
#  22.35,
#  23.4,
#  18.94,
#  10.72,
#  11.31,
#  11.31,
#  11.8,
#  11.8,
#  18.94,
#  16.91,
#  14.47,
#  11.8,
#  23.4,
#  17.97,
#  11.8,
#  19.92,
#  17.97,
#  26.31,
#  14.47,
#  23.4,
#  23.4,
#  20.89,
#  26.31,
#  14.47,
#  14.47,
#  16.14,
#  16.14,
#  12.98,
#  10.72,
#  23.4,
#  19.92,
#  10.33,
#  15.02,
#  17.97,
#  18.94,
#  11.31,
#  14.47,
#  17.97,
#  16.14,
#  16.14,
#  17.97,
#  12.98,
#  23.4,
#  6.46,
#  10.33,
#  14.47,
#  10.33,
#  27.27,
#  16.91,
#  15.02,
#  12.98,
#  14.47,
#  17.97,
#  16.14,
#  18.94,
#  11.31,
#  7.56,
#  12.98,
#  10.72,
#  14.47,
#  13.56,
#  13.56,
#  14.47,
#  12.98,
#  27.27,
#  16.14,
#  16.14,
#  11.31,
#  11.8,
#  7.56,
#  10.72,
#  11.8,
#  17.97,
#  11.31,
#  8.19,
#  16.91,
#  14.47,
#  11.31,
#  17.97,
#  8.19,
#  20.89,
#  27.27,
#  15.02,
#  17.97,
#  8.81,
#  14.47,
#  12.98,
#  11.31,
#  23.4,
#  16.14,
#  15.02,
#  14.47,
#  10.72,
#  14.47,
#  14.47,
#  8.81,
#  10.33,
#  18.94,
#  15.02,
#  30.75,
#  8.19,
# ...

# %%
#String
term_rate =' 15'
print(term_rate)

#Converting String to Integer
int_term_rate = int(term_rate)
print(int_term_rate)
# Out:
#  15
# 15

# %%
#Converting Object to Integer 
term_rate = "15"
term_rate_int = int(term_rate)
print(term_rate_int + 2)
# Out:
# 17

# %%
#Strip %
term_rate.strip()
# Out:
# '15.65%'

# %%
term_rate.strip('%')
# Out:
# ' 15.65'

# %%
 #Writing Function
  def term_conversion(cell_contents):
   return cell_contents.strip().strip('months')

# %%
#Test
term_conversion(int_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-08a61fa6df92> in <module>()
# ----> 1 term_conversion(int_rate)
#
# NameError: name 'int_rate' is not defined

# %%
type(term_conversion(term_rate))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-01f86b6e490c> in <module>()
# ----> 1 type(term_conversion(term_rate))
#
# NameError: name 'term_conversion' is not defined

# %% [markdown]
# Convert the term column from strings to integers

# %%
#Looking for the datatype of the term column
df['term'].dtypes
# Out:
# dtype('O')

# %%
#Output 1 cell from the column
df['term'][0]
# Out:
# ' 36 months'

# %%
#Assign above output to a variable

term = '36 months'

# %%
term.strip("months")
# Out:
# '36 '

# %%
# Here age is a string object
term = "36 "
print(term)
# Converting string to integer
int_term = int(term)
print(int_term)
# Out:
# 36
# 36

# %%
#Ned to see more rows in the 'term column'

df['term'].head(100)
# Out:
# 0      36 months
# 1      36 months
# 2      60 months
# 3      36 months
# 4      36 months
# 5      36 months
# 6      36 months
# 7      36 months
# 8      60 months
# 9      36 months
# 10     36 months
# 11     60 months
# 12     36 months
# 13     36 months
# 14     36 months
# 15     60 months
# 16     60 months
# 17     60 months
# 18     60 months
# 19     60 months
# 20     36 months
# 21     36 months
# 22     36 months
# 23     60 months
# 24     36 months
# 25     60 months
# 26     36 months
# 27     60 months
# 28     36 months
# 29     36 months
# 30     36 months
# 31     60 months
# 32     36 months
# 33     36 months
# 34     36 months
# 35     60 months
# 36     36 months
# 37     60 months
# 38     36 months
# 39     60 months
# 40     36 months
# 41     36 months
# 42     60 months
# 43     36 months
# 44     36 months
# 45     36 months
# 46     36 months
# 47     60 months
# 48     36 months
# 49     36 months
# 50     36 months
# 51     60 months
# ...

# %%
def loan_status_to_int(cell_contents):
  if cell == "Current" or cell == "Fully Paid":
    return 1
  else:
    return 0

# %%
examples = ['Fully Paid', 'Late (31-120 Days)', 'Current', 'Charged Off' ]

loan_status_as_int = []
for value in examples:
  loan_status_as_int.append(loan_status_to_int(value))
  
  loan_status_as_int
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-8813aa9a8608> in <module>()
#       3 loan_status_as_int = []
#       4 for value in examples:
# ----> 5   loan_status_as_int.append(loan_status_to_int(value))
#       6
#       7   loan_status_as_int
#
# <ipython-input-84-30887a978d91> in loan_status_to_int(cell_contents)
#       1 def loan_status_to_int(cell_contents):
# ----> 2   if cell == "Current" or cell == "Fully Paid":
#       3     return 1
#       4   else:
#       5     return 0
#
# NameError: name 'cell' is not defined

# %%
[col for col in df if col.endswith('_d')]

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
